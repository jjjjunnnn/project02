# %%
from tokenizer import Tokenizer
path = "/workspace/project02/imdb_dataset"
t = Tokenizer(dataset=path)

# %%
#device
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)

path = "/workspace/project02/imdb_dataset"
save_path = "/workspace/project02/checkpoint"
epochs = 60
batch = 16
model1 = "LSTM"
model2 = "VT"
# Out:
# cuda

# %%
from trainer import Trainer

trainer1 = Trainer(device=device,
                  dataset_path=path,
                  batch=batch,
                  model=model1,
                  epochs=epochs,
                  save_path=save_path)
trainer2 = Trainer(device=device,
                  dataset_path=path,
                  batch=batch,
                  model=model2,
                  epochs=epochs,
                  save_path=save_path)
# Out:
# 20000
# 20000

# %%
from trainer import Trainer
t = Trainer(device=device,
                  dataset_path=path,
                  batch=batch,
                  model=model2,
                  epochs=epochs,
                  save_path=save_path,
                  load_path="/workspace/project02/checkpoint/vt_03")
t.test()
# Out:
# 20000
# model:VT
# /workspace/project02/trainer.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(load_path, map_location=device)
# ...

# %%
trainer1.train("LSTM_01")
trainer1.test()
# Out:
# Epoch 1/60 [Train]: 100%|██████████| 1250/1250 [01:28<00:00, 14.09it/s, loss=0.649]
# Epoch 1 Summary: Train Loss: 0.6789 | Val Loss: 0.6469 | Val Acc: 63.52%
# Epoch 2/60 [Train]: 100%|██████████| 1250/1250 [01:29<00:00, 14.03it/s, loss=0.789]
# Epoch 2 Summary: Train Loss: 0.6516 | Val Loss: 0.6120 | Val Acc: 67.36%
# Epoch 3/60 [Train]:   9%|▉         | 110/1250 [00:08<01:24, 13.55it/s, loss=0.647]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trainer1.train("LSTM_01")
#       2 trainer1.test()
#
# File /workspace/project02/trainer.py:78, in Trainer.train(self, save_path_name, early_stop)
#      76 output = self.model(input, mask)
#      77 loss = self.loss(output, label)
# ---> 78 loss.backward()
#      79 self.optimizer.step()
#      81 train_loss += loss.item()
#
# ...
