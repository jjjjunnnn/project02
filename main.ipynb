# %%
# Out:
# cpu

# %%
#device
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)

path = "/home/parkjunsu/workspace/project02/imdb_dataset"
save_path = "/home/parkjunsu/workspace/project02/checkpoint"
epochs = 60
batch = 4
model = "VT"
# Out:
# cpu

# %%
from trainer import Trainer

trainer = Trainer(device=device,
                  dataset_path=path,
                  batch=batch,
                  model=model,
                  epochs=epochs,
                  save_path=save_path)

# %%
trainer.train()
trainer.test()
# Out:
# Epoch 1/60 [Train]:   0%|          | 1/1250 [00:05<1:53:34,  5.46s/it, loss=0.66]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 trainer.train()
#       2 trainer.test()
#
# File ~/workspace/project02/trainer.py:69, in Trainer.train(self, early_stop)
#      66 mask = batch['masks'].to(self.device)
#      67 label = batch['labels'].to(self.device)
# ---> 69 output = self.model(input, mask)
#      70 loss = self.loss(output, label)
#      71 loss.backward()
#
# File ~/miniconda3/envs/project02/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# ...
